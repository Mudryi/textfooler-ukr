# %%
import re
from collections import Counter
import pymorphy2
from prepare_synonym_dict import read_and_clean_synonym_dict

morph = pymorphy2.MorphAnalyzer(lang='uk')

def get_normal_form(word, morph):
    parsed = morph.parse(word)
    if parsed:
        return parsed[0].normal_form
    else:
        return word

path_to_ulif = '/home/mudryi/phd_projects/synonym_attack/synonyms_dictionaries/synonimy_info_clean.json'
synonym_dict = read_and_clean_synonym_dict(path_to_ulif, use_antonyms=True)
# Out:
# Processing synonym dict: 100%|██████████| 15157/15157 [00:04<00:00, 3534.66it/s]

# %%
with open("adv_results_reviews_xlm-roberta-base_synonym_info/adversaries.txt", "r", encoding="utf-8") as f:
    content = f.read()

replacement_pattern = re.findall(r"Replacements\s+\[(.*?)\]", content, re.DOTALL)

replacements = []
for group in replacement_pattern:
    group_clean = group.replace("\n", " ")
    pairs = re.findall(r"\('(.+?)', '(.+?)', \d+\)", group_clean)
    replacements.extend(pairs)

normalized_replacements = [(get_normal_form(orig, morph), subst) for orig, subst in replacements]

pair_counter = Counter(normalized_replacements)
top_100_raw = pair_counter.most_common(100)

# %%
top_100_raw
# Out:
# [(('чудовий', 'блискучий'), 91),
#  (('гарний', 'негарний'), 88),
#  (('гарний', 'поганий'), 70),
#  (('рекомендувати', 'характеризувати'), 68),
#  (('швидко', 'хутко'), 44),
#  (('якісний', 'добротний'), 38),
#  (('хороший', 'вродливий'), 33),
#  (('проблема', 'питання'), 28),
#  (('гарний', 'бридкий'), 27),
#  (('працювати', 'трудитися'), 23),
#  (('сподобатися', 'заімпонувати'), 23),
#  (('відмінний', 'несхожий'), 22),
#  (('працювати', 'партачити'), 21),
#  (('зручний', 'похватний'), 21),
#  (('взагалі', 'загалом'), 19),
#  (('нормальний', 'звичайний'), 18),
#  (('хороший', 'відмінний'), 17),
#  (('запах', 'аромат'), 16),
#  (('якість', 'характер'), 16),
#  (('працювати', 'ґарувати'), 16),
#  (('товар', 'крам'), 16),
#  (('працювати', 'гарувати'), 16),
#  (('сподобатися', 'подобатися'), 15),
#  (('вистачати', 'ставати'), 15),
#  (('чудовий', 'незрівняний'), 15),
#  (('якість', 'риса'), 15),
#  (('ціна', 'плата'), 15),
#  (('повністю', 'цілком'), 14),
#  (('швидкий', 'повільний'), 14),
#  (('товар', 'шкіра'), 14),
#  (('цілий', 'повний'), 14),
#  (('швидко', 'повільно'), 14),
#  (('смачний', 'ласий'), 14),
#  (('подобатися', 'імпонувати'), 13),
#  (('подарунок', 'дарунок'), 13),
#  (('гарно', 'блискуче'), 13),
#  (('повністю', 'дощенту'), 12),
#  (('відповідати', 'відказувати'), 12),
#  (('непоганий', 'гарний'), 12),
#  (('чудовий', 'прегарний'), 12),
#  (('працювати', 'капарити'), 12),
#  (('великий', 'немалий'), 12),
#  (('рекомендувати', 'пропонувати'), 12),
#  (('цілий', 'непочатий'), 11),
#  (('приємний', 'симпатичний'), 11),
#  (('найкращий', 'коронний'), 11),
#  (('кращий', 'ліпший'), 11),
#  (('якість', 'проба'), 11),
#  (('яскравий', 'сліпучий'), 11),
#  (('смак', 'присмак'), 11),
#  (('хороший', 'приємний'), 11),
#  (('швидко', 'прожогом'), 10),
#  (('користуватися', 'користатися'), 10),
#  (('тримати', 'держати'), 10),
#  (('легкий', 'невагомий'), 10),
#  (('користуватися', 'орудувати'), 10),
#  (('непоганий', 'порядний'), 10),
#  (('непоганий', 'незлий'), 9),
#  (('нормальний', 'здоровий'), 9),
#  (('приємний', 'милий'), 9),
#  (('даний', 'названий'), 9),
#  (('перший', 'початковий'), 9),
#  (('задоволення', 'втіха'), 9),
#  (('колір', 'забарвлення'), 9),
#  (('працювати', 'чинити'), 9),
#  (('непоганий', 'нічогенький'), 9),
#  (('гарно', 'добре'), 9),
#  (('сподобатися', 'злюбитися'), 9),
#  (('звук', 'звучання'), 9),
#  (('хотіти', 'жадати'), 8),
#  (('ціна', 'вартість'), 8),
#  (('гарний', 'хороший'), 8),
#  (('легко', 'вільно'), 8),
#  (('високий', 'низький'), 8),
#  (('думати', 'мізкувати'), 8),
#  (('стояти', 'стирчати'), 8),
#  (('якість', 'прикмета'), 8),
#  (('жахливий', 'страхітливий'), 8),
#  (('відправити', 'виганяти'), 8),
#  (('гарний', 'прегарний'), 8),
#  (('єдиний', 'цільний'), 8),
#  (('якісно', 'добротно'), 8),
#  (('нема', 'катма'), 8),
#  (('потрібний', 'доконечний'), 8),
#  (('гарний', 'вродливий'), 8),
#  (('купувати', 'придбавати'), 8),
#  (('купувати', 'дурити'), 8),
#  (('відповідати', 'відмовляти'), 8),
#  (('смачний', 'сласний'), 8),
#  (('міцний', 'сильний'), 8),
#  (('ціна', 'цінність'), 7),
#  (('швидко', 'стрімко'), 7),
#  (('аромат', 'запах'), 7),
#  (('зручний', 'спосібний'), 7),
#  (('потужний', 'громовий'), 7),
#  (('колір', 'барва'), 7),
#  (('достатньо', 'доволі'), 7),
#  (('працювати', 'робити'), 7),
#  (('позитивний', 'похвальний'), 7),
#  (('якість', 'рівень'), 7)]

# %%
approved_replacements = set([('гарний', 'непоганий'),
                             ('працювати', 'мозолитися'),
                             ('хороший', 'непоганий'),
                             ('рекомендувати', 'порекомендувати'),
                             ('чудовий', 'ладний'),
                             ('зручно', 'вигідно'),
                             ('чудовий', 'блискучий'),
                             ('якісний', 'тривкий'),
                             ('проблема', 'квестія'),
                             ('якісний', 'добірний'),
                             ('сподобатися', 'пригледітися'),
                             ('чудово', 'добре'),
                             ('хороший', 'нічогенький'),
                             ('якісний', 'добротний'),
                             ('гарно', 'непогано'),
                             ('смачний', 'ласий'),
                             ('приємний', 'нічогенький'),
                             ('швидко', 'хутко'),
                             ('зручний', 'ладний'),
                             ('взагалі', 'загалом'),
                             ('найкращий', 'оптимальний'),
                             ('гарно', 'ладно'),
                             ('запах', 'аромат'),
                             ('приємний', 'поманливий'),
                             ('ціна', 'вартість'),
                             ('робот', 'автомат'),
                             ('користуватися', 'послугуватися'),
                             ('приємно', 'втішно'),
                             ('працювати', 'гарувати'),
                             ('легко', 'ніпочім'),
                             ('працювати', 'трудитися'),
                             ('товар', 'крам'),
                             ('сподобатися', 'приглядітися'),
                             ('виробник', 'продуцент'),
                             ('хороший', 'ладний'),
                             ('пластик', 'пластмаса'),
                             ('вистачати', 'вистарчати'),
                             ('ціна', 'плата'),
                             ('гарний', 'ладний'),
                             ('дитина', 'крихітка'),
                             ('ціна', 'розцінка'),
                             ('смачний', 'смаковитий'),
                             ('сподобатися', 'імпонувати'),
                             ('легко', 'ніпочому'),
                             ('гарно', 'лацно'),
                             ('порадувати', 'обрадувати'),
                             ('чудово', 'навдивовижу'),
                             ('чудовий', 'хороший'),
                             ('покупка', 'покуп'),
                             ('приємно', 'гарно'),
                             ('рекомендувати', 'відрекомендовувати'),
                             ('рекомендувати', 'відрекомендувати'),
                             ('день', 'днина'),
                             ('сподобатися', 'подобатися'),
                             ('гарний', 'добрячий'),
                             ('хороший', 'добрячий'),
                             ('вистачати', 'вистарчити'),
                             ('працювати', 'функціонувати'),
                             ('проблема', 'питання'),
                             ('гарний', 'добренький'),
                             ('хороший', 'добренький'),
                             ('повністю', 'цілком'),
                             ('тиждень', 'седмиця'),
                             ('нормальний', 'пересічний'),
                             ('якісний', 'доброякісний'),
                             ('захват', 'піднесеність'),
                             ('чудово', 'напрочуд'),
                             ('подобатися', 'пригледітися'),
                             ('гріш', 'грошей'),
                             ('повністю', 'зовсім'),
                             ('гарний', 'порядний'),
                             ('хороший', 'добрий'),
                             ('сподобатися', 'любитися'),
                             ('гарний', 'прегарний'),
                             ('комплект', 'набір'),
                             ('найкращий', 'якнайліпший'),
                             ('смачно', 'усмак'),
                             ('замовити', 'замовляти'),
                             ('швидкий', 'поспішний'),
                             ('купити', 'придбавати'),
                             ('чудовий', 'розпрочудесний'),
                             ('цілком', 'унівець'),
                             ('приємний', 'ненаглядний'),
                             ('гарний', 'шатний'),
                             ('тиждень', 'седмиць'),
                             ('повністю', 'ущерть'),
                             ('смачно', 'всмак'),
                             ('комплект', 'гарнітур'),
                             ('нормальний', 'обичайний'),
                             ('хороший', 'прехороший'),
                             ('зручний', 'комфортабельний'),
                             ('радувати', 'обрадувати'),
                             ('швидко', 'поспішно'),
                             ('великий', 'нічогенький'),
                             ('великий', 'немалий'),
                             ('працювати', 'ґарувати'),
                             ('зручний', 'похватний'),
                             ('швидше', 'скоріший'),
                             ('нарікання', 'ієреміада'),
                             ('чудовий', 'прегарний'),
                             ('покупка', 'купівля'),
                             ('чудовий', 'незрівнянний'),
                             ('смачний', 'апетитний'),
                             ('користуватися', 'уживати'),
                             ('користуватися', 'спожити'),
                             ('вистачати', 'стачати'),
                             ('отримати', 'дістати'),
                             ('задоволення', 'усолода'),
                             ('волосся', 'волос'),
                             ('смачний', 'добрий'),
                             ('чудово', 'пречудесно'),
                             ('швидко', 'раптово'),
                             ('працювати', 'діяти'),
                             ('працювати', 'працюватися'),
                             ('хороший', 'пристойний'),
                             ('чудовий', 'неперевершений'),
                             ('сподобатися', 'приглянутися'),
                             ('гарний', 'пристойний'),
                             ('сподобатися', 'заімпонувати'),
                             ('хороший', 'вдалий'),
                             ('чудовий', 'розчудесний'),
                             ('сподобатися', 'полюблятися'),
                             ('найкращий', 'щонайліпший'),
                             ('улюблений', 'укоханий'),
                             ('надійний', 'вивірений'),
                             ('користуватися', 'застосовувати'),
                             ('чудовий', 'чудесний'),
                             ('міцно', 'туго'),
                             ('гарний', 'вродливий'),
                             ('гарно', 'лепсько'),
                             ('дитина', 'дитиня'),
                             ('радувати', 'тішити'),
                             ])

# %%
questionable_replacements = set([('швидко', 'побіжно'),
                                 ('швидко', 'поквапно'),
                                 ('швидко', 'поквапливо'),
                                 ('швидко', 'мерщій'),
                                 ('використовувати', 'витратити'),
                                 ('виконувати', 'провадити'),
                                 ('великий', 'превеликий'),
                                 ('великий', 'непомірний'),
                                 ('великий', 'неокраїй'),
                                 ('відмінний', 'несхожий'),
                                 ('відмінний', 'неподібний'),
                                 ('відмінний', 'неоднаковий'),
                                 ('чудовий', 'подобний'),
                                 ('чудовий', 'вродливий'),
                                 ('чудовий', 'хупавий'),
                                 ('чудовий', 'шатний'),
                                 ('чудовий', 'доладний'),
                                 ('чудовий', 'уродливий'),
                                 ('міцний', 'непіддатливий'),
                                 ('перший', 'нульовий'),
                                 ('працювати', 'труждатися'),
                                 ('прекрасний', 'доладний'),
                                 ('відповідати', 'збігтися'),
                                 ('якість', 'риса'),
                                 ('якість', 'ознака'),
                                 ('якість', 'особливість'),
                                 ('якість', 'познака'),
                                 ('якість', 'властивість'),
                                 ('єдиний', 'цільний'),
                                 ('єдиний', 'цілий'),
                                 ('єдиний', 'цілісний'),
                                 ('компактний', 'щільний'),
                                 ('комплект', 'прибор'),
                                 ('користуватися', 'зужиткувати'),
                                 ('надійний', 'певний'),
                                 ('можливість', 'перспектива'),
                                 ('відповідати', 'відказувати'),
                                 ('хороший', 'доладний'),
                                 ('хороший', 'уродливий'),
                                 ('мати', 'мусити'),
                                 ('мати', 'почувати'),
                                 ('мати', 'володіти'),
                                 ('міцний', 'несхитний'),
                                 ('гарно', 'порядно'),
                                 ('гарний', 'хупавий'),
                                 ('гарний', 'доладний'),
                                 ('гарний', 'уродливий'),
                                 ('радувати', 'вабити'),
                                 ('різний', 'несхожий'),
                                 ('режим', 'розпорядок'),
                                 ('замовлення', 'заявка'),
                                 ('замовити', 'змовити'),
                                 ('зручний', 'догідний'),
                                 ('крутий', 'високий'),
                                 ('видно', 'мабуть'),
                                 ('цікавий', 'небезінтересний'),
                                 ('працювати', 'увихатися'),
])

# %%
top_100_filtered = [pair for pair in top_100_raw if pair[0] not in approved_replacements]
top_100_filtered = [pair for pair in top_100_filtered if pair[0] not in questionable_replacements]

print(f"Found {len(top_100_filtered)} new replacements to review:")
for (orig, sub), count in top_100_filtered:
    print(f"('{orig}', '{sub}'),")
# Out:
# Found 75 new replacements to review:
# ('гарний', 'негарний'),
# ('гарний', 'поганий'),
# ('рекомендувати', 'характеризувати'),
# ('хороший', 'вродливий'),
# ('гарний', 'бридкий'),
# ('працювати', 'партачити'),
# ('нормальний', 'звичайний'),
# ('хороший', 'відмінний'),
# ('якість', 'характер'),
# ('вистачати', 'ставати'),
# ('чудовий', 'незрівняний'),
# ('швидкий', 'повільний'),
# ('товар', 'шкіра'),
# ('цілий', 'повний'),
# ('швидко', 'повільно'),
# ('подобатися', 'імпонувати'),
# ('подарунок', 'дарунок'),
# ('гарно', 'блискуче'),
# ('повністю', 'дощенту'),
# ('непоганий', 'гарний'),
# ('працювати', 'капарити'),
# ('рекомендувати', 'пропонувати'),
# ('цілий', 'непочатий'),
# ('приємний', 'симпатичний'),
# ('найкращий', 'коронний'),
# ('кращий', 'ліпший'),
# ('якість', 'проба'),
# ('яскравий', 'сліпучий'),
# ('смак', 'присмак'),
# ('хороший', 'приємний'),
# ('швидко', 'прожогом'),
# ('користуватися', 'користатися'),
# ('тримати', 'держати'),
# ('легкий', 'невагомий'),
# ('користуватися', 'орудувати'),
# ('непоганий', 'порядний'),
# ('непоганий', 'незлий'),
# ('нормальний', 'здоровий'),
# ('приємний', 'милий'),
# ('даний', 'названий'),
# ('перший', 'початковий'),
# ('задоволення', 'втіха'),
# ('колір', 'забарвлення'),
# ('працювати', 'чинити'),
# ('непоганий', 'нічогенький'),
# ('гарно', 'добре'),
# ('сподобатися', 'злюбитися'),
# ('звук', 'звучання'),
# ('хотіти', 'жадати'),
# ('гарний', 'хороший'),
# ('легко', 'вільно'),
# ('високий', 'низький'),
# ('думати', 'мізкувати'),
# ('стояти', 'стирчати'),
# ('якість', 'прикмета'),
# ('жахливий', 'страхітливий'),
# ('відправити', 'виганяти'),
# ('якісно', 'добротно'),
# ('нема', 'катма'),
# ('потрібний', 'доконечний'),
# ('купувати', 'придбавати'),
# ('купувати', 'дурити'),
# ('відповідати', 'відмовляти'),
# ('смачний', 'сласний'),
# ('міцний', 'сильний'),
# ('ціна', 'цінність'),
# ('швидко', 'стрімко'),
# ('аромат', 'запах'),
# ('зручний', 'спосібний'),
# ('потужний', 'громовий'),
# ('колір', 'барва'),
# ('достатньо', 'доволі'),
# ('працювати', 'робити'),
# ('позитивний', 'похвальний'),
# ('якість', 'рівень'),

# %%
import re
import pandas as pd

def parse_synonym_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()

    # Split entries by 'text {id}'
    entries = re.split(r'\btext (\d+)', content)[1:]  # Skip empty start
    
    parsed_data = []
    
    # Process in chunks of [id, entry]
    for i in range(0, len(entries), 2):
        text_id = int(entries[i])
        entry = entries[i+1]
        
        # Extract original sentence
        orig_match = re.search(r'orig sent \(\d+\):\s*(.+?)\s*adv sent', entry, re.DOTALL)
        original_sentence = orig_match.group(1).strip() if orig_match else None
        
        # Extract adversarial sentence
        adv_match = re.search(r'adv sent \(\d+\):\s*(.+?)\s*Replacements', entry, re.DOTALL)
        adversarial_sentence = adv_match.group(1).strip() if adv_match else None
        
        # Extract replacements list
        replacements_match = re.search(r"Replacements\s+\[(.*?)\]", entry, re.DOTALL)
        replacements_raw = replacements_match.group(1).replace("\n", " ") if replacements_match else ""
        replacements = re.findall(r"\('(.+?)',\s*'(.+?)',\s*\d+\)", replacements_raw)
        
        parsed_data.append({
            "text_id": text_id,
            "original_sentence": original_sentence,
            "adversarial_sentence": adversarial_sentence,
            "replacements": replacements
        })
    
    return pd.DataFrame(parsed_data)

df = parse_synonym_file("adv_results_reviews_sentence_transformer/adversaries.txt")
df.head()
# Out:
#    text_id                                  original_sentence  \
# 0        0  Придбав 2 кабелі. На коробці напис "Быстрая си...
# 1        8  Вчора замовила, сьогодні забрала у відділенні ...
# 2       13  Брав комплект з пральною машиною і вийшла гарн...
# 3       14  не поганий шампунь, гарно захищає фарбоване во...
# 4       20  Тримен чудово відпрацював 1 рік і 11 місяців, ...
#
#                                 adversarial_sentence  \
# 0  Придбав 2 кабелі. На коробці напис "Быстрая си...
# 1  Учора примовляла, сьогодні прихватила у відділ...
# 2  Брав комплект з пральною машиною і вийшла гарн...
# 3  не поганий шампунь, ладно заборонить фарбоване...
# 4  Тримен знаменито відпрацював 1 рік і 11 місяці...
#
#                                         replacements
# 0  [(достатньо, предосить), (домашніх, свійський)...
# 1  [(нема, трясцяма), (нарікань, скарга), (Праску...
# 2               [(зручно, вигідно), (тиха, слабкий)]
# 3            [(захищає, заборонити), (гарно, ладно)]
# 4                              [(чудово, знаменито)]

# %%
len(df)
# Out:
# 3538

# %%
total = 0

# %%
total +=1

df.sample()[['original_sentence', 'adversarial_sentence', 'replacements']].values, total
# Out:
# (array([['Звичайно, є і кращі, і крутіші. А цей варіант - недорогий, відповідно, щось десь може не влаштовувати. Пристрій доволі простий і бюджетний. Працює - норм.',
#          'Звичайно, є і кращі, і крутіші. А цей варіант - недорогий, відповідно, щось десь може не влаштовувати. Установка доволі простий і бюджетний. Працює - узусу.',
#          list([('Пристрій', 'установка'), ('норм', 'узус')])]],
#        dtype=object),
#  30)

# %%
# xml-roberta (0.43333333333333335, 0.4666666666666667)  ///(0.24, 0.52)
good = 10
disambiguatioan = 0
bad_replacement = 20
bad_grammar = 0

good/(total), bad_replacement/(total)
# Out:
# (0.3333333333333333, 0.6666666666666666)

# %%
synonym_dict['побачити']
# Out:
# ['діждатися',
#  'вгледіти',
#  'розчовпат',
#  'назнават',
#  'ділити',
#  'зочити',
#  'спізнати',
#  'повидати',
#  'стрівата',
#  'зустрічати',
#  'установлювати',
#  'дострибатися',
#  'устрінути',
#  'пострічата',
#  'зустріват',
#  'знаходити',
#  'дізнават',
#  'дочекатися',
#  'спобігати',
#  'вздріватися',
#  'стрінутися',
#  'взнавати',
#  'пізнаватися',
#  'встрінута',
#  'наглядіти',
#  'заздріти',
#  'відкрити',
#  'докотитися',
#  'дожитися',
#  'зоглядіти',
#  'перестрічати',
#  'зазнати',
#  'зустрінутися',
#  'докочуватися',
#  'перестрінутися',
#  'взнати',
#  'подибати',
#  'повидіти',
#  'устріти',
#  'стрінути',
#  'згледітися',
#  'підмітити',
#  'взорити',
#  'узнати',
#  'стрітися',
#  'повидата',
#  'видати',
#  'зустрінути',
#  'побачитися',
#  'виявити',
#  'дійти',
#  'дограватися',
#  'доплигатися',
#  'нагледіти',
#  'зогледіти',
#  'зглядіти',
#  'доглянути',
#  'наглянути',
#  'зочита',
#  'зустрівати',
#  'встановлювати',
#  'підмічати',
#  'доплигуватися',
#  'назнавата',
#  'спізнавати',
#  'натрапити',
#  'поназдивитися',
#  'стріват',
#  'подибатися',
#  'зріти',
#  'стріти',
#  'доживати',
#  'здріти',
#  'перестрівати',
#  'узорити',
#  'перестріти',
#  'дізнатися',
#  'встрінути',
#  'зглядітися',
#  'установити',
#  'спіткатися',
#  'дожити',
#  'пострічат',
#  'достукатися',
#  'дізнавати',
#  'дізнавата',
#  'переживати',
#  'дізнаватися',
#  'повидат',
#  'дознатися',
#  'зустрітися',
#  'вздріти',
#  'взріти',
#  'увидіти',
#  'подибувати',
#  'уздріватися',
#  'бачитися',
#  'здибати',
#  'надибувати',
#  'забачитися',
#  'розчовпати',
#  'заглянути',
#  'вздрітися',
#  'догратися',
#  'бачити',
#  'зогледітися',
#  'уздріти',
#  'зазнавати',
#  'зустрічатися',
#  'дознавата',
#  'поділяти',
#  'дознаватися',
#  'постерегти',
#  'дострибуватися',
#  'повидатися',
#  'дознавати',
#  'згледіта',
#  'набачити',
#  'узріти',
#  'заживати',
#  'надибати',
#  'здибуват',
#  'дивитися',
#  'здибувата',
#  'лицезріти',
#  'звідувати',
#  'загледіти',
#  'згледіти',
#  'назнавати',
#  'стрічатися',
#  'достукуватися',
#  'встановити',
#  'дожидати',
#  'знайти',
#  'назирити',
#  'пізнавати',
#  'назнати',
#  'помітити',
#  'помічати',
#  'узнавати',
#  'перестрінути',
#  'уздрітися',
#  'дізнати',
#  'пізнатися',
#  'звідати',
#  'здибувати',
#  'вглядіти',
#  'взорит',
#  'дознати',
#  'дознават',
#  'спобігти',
#  'встріти',
#  'дочікуватися',
#  'знати',
#  'дочекати',
#  'зобачитися',
#  'пізнати',
#  'виявляти',
#  'стрівати',
#  'спостерегти',
#  'пережити',
#  'зогледіта',
#  'надивитися',
#  'заглядіти',
#  'набачита',
#  'звидіти',
#  'дожидатися',
#  'зажити',
#  'подибуватися',
#  'спіткати',
#  'діждати',
#  'угледіти',
#  'доходити',
#  'пострічати',
#  'знатися',
#  'зоглядітися',
#  'поділити',
#  'зустріти',
#  'устрінута',
#  'углядіти',
#  'доживатися',
#  'перестрітися',
#  'відкривати',
#  'видіти',
#  'стрічати',
#  'зуздріти']

# %%
morph.parse('чарівне')[0].normal_form
# Out:
# 'чарівний'
